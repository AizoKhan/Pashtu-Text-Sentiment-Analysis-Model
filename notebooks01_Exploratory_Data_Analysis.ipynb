# %% [markdown]
# # EDA: Pashtu Sentiment Dataset

# %%
import pandas as pd
df = pd.read_excel('../data/Pashtu Text Sentiment Analysis Dataset.xlsx')
df.head()

# %%
from utils.helpers import plot_label_distribution
plot_label_distribution(df, save_path='../outputs/results/label_dist.png')
